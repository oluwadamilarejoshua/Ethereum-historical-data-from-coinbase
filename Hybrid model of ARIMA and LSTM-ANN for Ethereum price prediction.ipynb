# %%
import requests
import json
from bs4 import BeautifulSoup as bs

# %%
url = 'https://api.coinbase.com/v2/prices/ETH-USD/spot'
response = requests.get(url)
ethereum_price_series = json.loads(response.text)
ethereum_price_series
# Out:
# {'data': {'base': 'ETH', 'currency': 'USD', 'amount': '1589.75'}}

# %%
url = 'https://api.pro.coinbase.com/products/ETH-USD/candles?start=&end={2}&granularity={3}'
response = requests.get(url)
ethereum_price_series = json.loads(response.text)
ethereum_price_series

https://pro-api.coinmarketcap.com

# %%
url = 'https://api.coinbase.com/v2/prices/ETH-USD/historic?start=&end=20200101&granularity=daily'
response = requests.get(url)
ethereum_price_series = json.loads(response.text)
ethereum_price_series
# Out:
# {'data': {'base': 'ETH',
#   'currency': 'USD',
#   'prices': [{'price': '1632.74', 'time': '2022-07-22T11:47:20Z'},
#    {'price': '1630.76', 'time': '2022-07-22T11:47:10Z'},
#    {'price': '1631.77', 'time': '2022-07-22T11:47:00Z'},
#    {'price': '1630.32', 'time': '2022-07-22T11:46:50Z'},
#    {'price': '1630.65', 'time': '2022-07-22T11:46:40Z'},
#    {'price': '1631.17', 'time': '2022-07-22T11:46:30Z'},
#    {'price': '1632.72', 'time': '2022-07-22T11:46:20Z'},
#    {'price': '1635.05', 'time': '2022-07-22T11:46:10Z'},
#    {'price': '1634.32', 'time': '2022-07-22T11:46:00Z'},
#    {'price': '1634.38', 'time': '2022-07-22T11:45:50Z'},
#    {'price': '1634.19', 'time': '2022-07-22T11:45:40Z'},
#    {'price': '1634.71', 'time': '2022-07-22T11:45:30Z'},
#    {'price': '1634.33', 'time': '2022-07-22T11:45:20Z'},
#    {'price': '1634.19', 'time': '2022-07-22T11:45:10Z'},
#    {'price': '1633.73', 'time': '2022-07-22T11:45:00Z'},
# ...

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/ohlcv/historical?id=1&time_start=2019-06-01&interval=weekly&#8221'
response = requests.get(url)
ethereum_price_series = json.loads(response.text)
ethereum_price_series
# Out:
# {'status': {'timestamp': '2022-07-22T12:03:17.487Z',
#   'error_code': 1002,
#   'error_message': 'API key missing.',
#   'elapsed': 0,
#   'credit_count': 0}}

# %%
pip install cryptocmd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
