# %%
from cryptocmd import CmcScraper
import pandas as pd
import numpy as np
import pylab as p
import matplotlib.pyplot as plot
from collections import Counter
import re
import math

import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.formula.api as smf
from statsmodels.tsa.arima.model import ARIMA

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score
from vecstack import stacking
# from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM
from itertools import cycle
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from matplotlib import pyplot
import pylab as py
print('All good!')
# Out:
# C:\Users\OLUWADAMILARE\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\OLUWADAMILARE\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# All good!

# %%
scraper_train = CmcScraper("ETH","04-08-2010", "03-08-2022")
train_xrp_json_data = scraper_train.get_data("json")
df_train = scraper_train.get_dataframe()[['Date', 'Close']]
df_train.head()
# Out:
#         Date        Close
# 0 2022-08-03  1618.874543
# 1 2022-08-02  1632.945439
# 2 2022-08-01  1635.195792
# 3 2022-07-31  1681.517319
# 4 2022-07-30  1695.969500

# %%
### QQ plot

sm.qqplot(df_train[['Close']], line = '45')
py.show()
# Out:
# C:\Users\OLUWADAMILARE\AppData\Roaming\Python\Python39\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
df_train.shape
# Out:
# (2554, 2)

# %% [markdown]
# Exploratory Analysis

# %%
# Time as index

train = df_train.set_index('Date')
train.sort_index(inplace=True)
print(type(train))
train.head

plot.plot(train)
plot.xlabel('Date', fontsize=12)
plot.ylabel('Price in USD', fontsize=12)
plot.title('Closing price distribution of Ethereum', fontsize=15)
plot.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Stationary test

# %%
from statsmodels.tsa.stattools import adfuller

def test_stationarity(x):


    #Determing rolling statistics
    rolmean = x.rolling(window=22,center=False).mean()

    rolstd = x.rolling(window=12,center=False).std()
    
    #Plot rolling statistics:
    orig = plot.plot(x, color='blue',label='Original')
    mean = plot.plot(rolmean, color='red', label='Moving Average')
    std = plot.plot(rolstd, color='black', label = 'Rolling Std')
    plot.legend(loc='best')
    plot.title('Moving Average & Standard Deviation')
    plot.show(block=False)
    
    #Perform Dickey Fuller test    
    result=adfuller(x)
    print('ADF Stastistic: %f'%result[0])
    print('p-value: %f'%result[1])
    pvalue=result[1]
    for key,value in result[4].items():
         if result[0]>value:
            print("The graph is non stationery")
            break
         else:
            print("The graph is stationery")
            break;
    print('Critical values:')
    for key,value in result[4].items():
        print('\t%s: %.3f ' % (key, value))
        
ts = train['Close']      
test_stationarity(ts)
# Out:
# ADF Stastistic: -1.408194
# p-value: 0.578342
# The graph is non stationery
# Critical values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567

# %% [markdown]
# Series transformation

# %%
ts_log = np.log(ts)
plot.plot(ts_log,color="green")
plot.show()

test_stationarity(ts_log)
# Out:
# ADF Stastistic: -2.089647
# p-value: 0.248698
# The graph is non stationery
# Critical values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567

# %% [markdown]
# Differencing the series

# %%
ts_log_diff = ts_log - ts_log.shift()
plot.plot(ts_log_diff)
plot.show()

# %%
ts_log_diff.dropna(inplace=True)
test_stationarity(ts_log_diff)
# Out:
# ADF Stastistic: -9.375040
# p-value: 0.000000
# The graph is stationery
# Critical values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567

# %%
sm.qqplot(ts_log_diff, line = '45')
py.show()
# Out:
# C:\Users\OLUWADAMILARE\AppData\Roaming\Python\Python39\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %% [markdown]
# AutoRegressive Integrated Moving Average (ARIMA) model

# %%
# follow lag
model = ARIMA(ts_log, order=(1,1,0))  
results_ARIMA = model.fit()  
plot.plot(ts_log_diff)
plot.plot(results_ARIMA.fittedvalues, color='red')
plot.title('RSS: %.7f'% sum((results_ARIMA.fittedvalues-ts_log_diff)**2))
plot.show()
# Out:
# C:\Users\OLUWADAMILARE\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\OLUWADAMILARE\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\OLUWADAMILARE\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'

# %%
# fit model
model = ARIMA(ts_log, order=(2,1,0))
model_fit = model.fit()
# summary of fit model
print(model_fit.summary())
# line plot of residuals
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
# density plot of residuals
residuals.plot(kind='kde')
pyplot.show()
# Out:
# C:\Users\OLUWADAMILARE\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\OLUWADAMILARE\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\OLUWADAMILARE\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 2554
# Model:                 ARIMA(2, 1, 0)   Log Likelihood                3351.298
# Date:                Sat, 13 Aug 2022   AIC                          -6696.597
# Time:                        09:49:49   BIC                          -6679.062
# Sample:                    08-07-2015   HQIC                         -6690.237
#                          - 08-03-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0270      0.015      1.814      0.070      -0.002       0.056
# ar.L2          0.0452      0.014      3.338      0.001       0.019       0.072
# sigma2         0.0042   2.12e-05    200.242      0.000       0.004       0.004
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):            489057.37
# Prob(Q):                              0.80   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.34   Skew:                            -3.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                        70.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# summary stats of residuals
print(residuals.describe())
plot.plot(ts_log_diff)
plot.plot(model_fit.fittedvalues, color='red')
plot.title('RSS: %.7f'% sum((model_fit.fittedvalues-ts_log_diff)**2))
plot.show()
# Out:
#                  0
# count  2554.000000
# mean      0.002714
# std       0.068128
# min      -1.302871
# 25%      -0.023830
# 50%       0.000504
# 75%       0.029049
# max       1.019612

# %% [markdown]
# Model Assessment

# %%
size = int(len(ts_log)-100)
# Divide into train and test
train_arima, test_arima = ts_log[0:size], ts_log[size:len(ts_log)]
history = [x for x in train_arima]
predictions = list()
originals = list()
error_list = list()

print('Printing Predicted vs Expected Values...')
print('\n')
# We go over each value in the test set and then apply ARIMA model and calculate the predicted value. We have the expected value in the test set therefore we calculate the error between predicted and expected value 
for t in range(len(test_arima)):
    model = ARIMA(history, order=(2, 1, 0))
    model_fit = model.fit()
    
    output = model_fit.forecast()
    
    pred_value = output[0]
    
        
    original_value = test_arima[t]
    history.append(original_value)
    
    pred_value = np.exp(pred_value)
    
    
    original_value = np.exp(original_value)
    
    # Calculating the error
    error = ((abs(pred_value - original_value)) / original_value) * 100
    error_list.append(error)
    print('predicted = %f,   expected = %f,   error = %f ' % (pred_value, original_value, error), '%')
    
    predictions.append(float(pred_value))
    originals.append(float(original_value))
    
# After iterating over whole test set the overall mean error is calculated.   
print('\n Mean Error in Predicting Test Case Articles : %f ' % (sum(error_list)/float(len(error_list))), '%')
plot.figure(figsize=(8, 6))
test_day = [t
           for t in range(len(test_arima))]
labels={'Orginal','Predicted'}
plot.plot(test_day, predictions, color= 'green')
plot.plot(test_day, originals, color = 'orange')
plot.title('Expected Vs Predicted Views Forecasting')
plot.xlabel('Day')
plot.ylabel('Closing Price')
plot.legend(labels)
plot.show()
# Out:
# Printing Predicted vs Expected Values...
#
#
# predicted = 3011.200215,   expected = 2808.298332,   error = 7.225083  %
# predicted = 2806.319278,   expected = 2888.929765,   error = 2.859553  %
# predicted = 2882.898157,   expected = 2936.941016,   error = 1.840107  %
# predicted = 2941.756302,   expected = 2815.601897,   error = 4.480548  %
# predicted = 2814.238110,   expected = 2730.186822,   error = 3.078591  %
# predicted = 2723.078160,   expected = 2827.756144,   error = 3.701804  %
# predicted = 2826.905687,   expected = 2857.410518,   error = 1.067569  %
# predicted = 2862.366719,   expected = 2783.476209,   error = 2.834244  %
# predicted = 2782.641228,   expected = 2940.644827,   error = 5.373094  %
# predicted = 2941.945882,   expected = 2749.213042,   error = 7.010473  %
']
scaler=MinMaxScaler(feature_range=(0,1))
closedf=scaler.fit_transform(np.array(closedf).reshape(-1,1))
print(closedf.shape)
# Out:
# (2554, 1)

# %%
training_size=int(len(closedf)*0.80)
test_size=len(closedf)-training_size
train_data,test_data=closedf[0:training_size,:],closedf[training_size:len(closedf),:1]
print("train_data: ", train_data.shape)
print("test_data: ", test_data.shape)
# Out:
# train_data:  (2043, 1)
# test_data:  (511, 1)

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 7
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test", y_test.shape)
# Out:
# X_train:  (2035, 7)
# y_train:  (2035,)
# X_test:  (503, 7)
# y_test (503,)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

print("X_train: ", X_train.shape)
print("X_test: ", X_test.shape)
# Out:
# X_train:  (2035, 7, 1)
# X_test:  (503, 7, 1)

# %%
model=Sequential()

model.add(LSTM(10,input_shape=(None,1),activation="relu"))

model.add(Dense(1))

model.compile(loss="mean_squared_error",optimizer="adam")

# %%
history = model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=1500,batch_size=50,verbose=1)
# Out:
# Epoch 1/1500
# 41/41 [==============================] - 3s 15ms/step - loss: 0.0974 - val_loss: 0.0014
# Epoch 2/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0705 - val_loss: 0.0011
# Epoch 3/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0448 - val_loss: 9.6787e-05
# Epoch 4/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0139 - val_loss: 3.5632e-05
# Epoch 5/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 6.6191e-04 - val_loss: 9.7213e-06
# Epoch 6/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 5.4359e-04 - val_loss: 4.6995e-06
# Epoch 7/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 5.2219e-04 - val_loss: 2.0547e-06
# Epoch 8/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 5.1989e-04 - val_loss: 6.3854e-06
# Epoch 9/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 5.0518e-04 - val_loss: 4.0952e-06
# Epoch 10/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 5.0262e-04 - val_loss: 6.7480e-06
# Epoch 11/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 4.8945e-04 - val_loss: 2.3407e-05
# Epoch 12/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 4.8232e-04 - val_loss: 1.0448e-06
# Epoch 13/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 4.7380e-04 - val_loss: 1.9303e-05
# Epoch 14/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 4.6216e-04 - val_loss: 1.6875e-07
# Epoch 15/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 4.6205e-04 - val_loss: 2.2624e-06
# Epoch 16/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 4.4910e-04 - val_loss: 3.4186e-07
# Epoch 17/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 4.4400e-04 - val_loss: 6.9320e-05
# Epoch 18/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 4.5470e-04 - val_loss: 1.1529e-05
# Epoch 19/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 4.3151e-04 - val_loss: 4.9171e-06
# Epoch 20/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 4.2807e-04 - val_loss: 6.1076e-06
# Epoch 21/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 4.2299e-04 - val_loss: 5.5661e-08
# Epoch 22/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 4.1834e-04 - val_loss: 6.5981e-06
# Epoch 23/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 4.0874e-04 - val_loss: 5.3035e-07
# Epoch 24/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 3.9542e-04 - val_loss: 3.1563e-08
# Epoch 25/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 3.9091e-04 - val_loss: 5.1723e-08
# Epoch 26/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 3.8610e-04 - val_loss: 8.8364e-06
# Epoch 27/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 3.9429e-04 - val_loss: 4.0179e-06
# Epoch 28/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 3.7971e-04 - val_loss: 2.2146e-06
# Epoch 29/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 3.6821e-04 - val_loss: 2.8575e-06
# Epoch 30/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 3.6174e-04 - val_loss: 1.2769e-05
# Epoch 31/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 3.7138e-04 - val_loss: 5.1969e-06
# Epoch 32/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 3.6883e-04 - val_loss: 2.9954e-05
# Epoch 33/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 3.6165e-04 - val_loss: 8.1872e-06
# Epoch 34/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 3.5355e-04 - val_loss: 7.0519e-06
# Epoch 35/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 3.5306e-04 - val_loss: 4.3904e-06
# Epoch 36/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 3.5521e-04 - val_loss: 5.7695e-06
# Epoch 37/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 3.4926e-04 - val_loss: 5.7500e-07
# Epoch 38/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 3.5946e-04 - val_loss: 3.1300e-06
# Epoch 39/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 3.3956e-04 - val_loss: 3.3036e-06
# Epoch 40/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 3.4324e-04 - val_loss: 1.6065e-05
# Epoch 41/1500
# 41/41 [==============================] - 0s 5ms/step - loss:
1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.2605e-04 - val_loss: 2.2170e-06
# Epoch 1471/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.2987e-04 - val_loss: 7.5693e-08
# Epoch 1472/1500
# 41/41 [==============================] - 0s 4ms/step - loss: 2.2865e-04 - val_loss: 1.8659e-07
# Epoch 1473/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.2447e-04 - val_loss: 1.6271e-06
# Epoch 1474/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 2.2642e-04 - val_loss: 3.4468e-07
# Epoch 1475/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.2573e-04 - val_loss: 1.3639e-06
# Epoch 1476/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.2561e-04 - val_loss: 1.0883e-05
# Epoch 1477/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.3178e-04 - val_loss: 2.0483e-05
# Epoch 1478/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.2498e-04 - val_loss: 6.6408e-07
# Epoch 1479/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 2.2565e-04 - val_loss: 5.5636e-06
# Epoch 1480/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.2897e-04 - val_loss: 4.2676e-06
# Epoch 1481/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.3457e-04 - val_loss: 4.4687e-06
# Epoch 1482/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 2.4002e-04 - val_loss: 3.4927e-06
# Epoch 1483/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.3123e-04 - val_loss: 1.9853e-06
# Epoch 1484/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.3398e-04 - val_loss: 8.3024e-08
# Epoch 1485/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.2560e-04 - val_loss: 2.0442e-06
# Epoch 1486/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.3069e-04 - val_loss: 4.5913e-07
# Epoch 1487/1500
# 41/41 [==============================] - 0s 4ms/step - loss: 2.3470e-04 - val_loss: 2.7633e-05
# Epoch 1488/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.3724e-04 - val_loss: 6.0331e-08
# Epoch 1489/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 2.2737e-04 - val_loss: 8.3318e-07
# Epoch 1490/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.2913e-04 - val_loss: 1.1379e-06
# Epoch 1491/1500
# 41/41 [==============================] - 0s 4ms/step - loss: 2.3465e-04 - val_loss: 5.2568e-06
# Epoch 1492/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.3101e-04 - val_loss: 2.5278e-07
# Epoch 1493/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.3720e-04 - val_loss: 5.0050e-06
# Epoch 1494/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 2.2589e-04 - val_loss: 4.5557e-08
# Epoch 1495/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.2497e-04 - val_loss: 1.8985e-05
# Epoch 1496/1500
# 41/41 [==============================] - 0s 4ms/step - loss: 2.3372e-04 - val_loss: 1.4010e-06
# Epoch 1497/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.3356e-04 - val_loss: 1.1697e-07
# Epoch 1498/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.2426e-04 - val_loss: 6.0962e-06
# Epoch 1499/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.3190e-04 - val_loss: 2.7047e-06
# Epoch 1500/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 2.2630e-04 - val_loss: 6.0526e-08

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

plot.plot(epochs, loss, 'r', label='Training loss')
plot.plot(epochs, val_loss, 'b', label='Validation loss')
plot.title('Training and validation loss')
plot.legend(loc=0)
plot.figure()


plot.show()

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
train_predict.shape, test_predict.shape
# Out:
# 64/64 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# ((2035, 1), (503, 1))

# %%
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
original_ytrain = scaler.inverse_transform(y_train.reshape(-1,1)) 
original_ytest = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
print("Train data RMSE: ", math.sqrt(mean_squared_error(original_ytrain,train_predict)))
print("Train data MSE: ", mean_squared_error(original_ytrain,train_predict))
print("Train data MAE: ", mean_absolute_error(original_ytrain,train_predict))
print("-------------------------------------------------------------------------------------")
print("Test data RMSE: ", math.sqrt(mean_squared_error(original_ytest,test_predict)))
print("Test data MSE: ", mean_squared_error(original_ytest,test_predict))
print("Test data MAE: ", mean_absolute_error(original_ytest,test_predict))
# Out:
# Train data RMSE:  71.2977766910405
# Train data MSE:  5083.372961085478
# Train data MAE:  35.29708369570939
# -------------------------------------------------------------------------------------
# Test data RMSE:  1.1837693880080056
# Test data MSE:  1.4013099639848483
# Test data MAE:  1.0638506175092908

# %%
print("Train data explained variance regression score:", 
      explained_variance_score(original_ytrain, train_predict))
print("Test data explained variance regression score:", 
      explained_variance_score(original_ytest, test_predict))
# Out:
# Train data explained variance regression score: 0.9963876128895427
# Test data explained variance regression score: 0.9862695209215547

# %%
print("Train data R2 score:", r2_score(original_ytrain, train_predict))
print("Test data R2 score:", r2_score(original_ytest, test_predict))
# Out:
# Train data R2 score: 0.9963875289861805
# Test data R2 score: 0.9461205893883725

# %%
close_stock = closedf = X_train
# close_stock.head

# %%
look_back = 7
trainPredictPlot = np.empty_like(closedf)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
print("Train predicted data: ", trainPredictPlot.shape)

# shift test predictions for plotting
testPredictPlot = np.empty_like(closedf)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(closedf)-1, :] = test_predict
print("Test predicted data: ", testPredictPlot.shape)

names = cycle(['Original close price','Train predicted close price','Test predicted close price'])


plotdf = pd.DataFrame({'date': close_stock['Date'],
                       'original_close': close_stock['Close'],
                      'train_predicted_close': trainPredictPlot.reshape(1,-1)[0].tolist(),
                      'test_predicted_close': testPredictPlot.reshape(1,-1)[0].tolist()})

fig = px.line(plotdf,x=plotdf['date'], y=[plotdf['original_close'],plotdf['train_predicted_close'],
                                          plotdf['test_predicted_close']],
              labels={'value':'Stock price','date': 'Date'})
fig.update_layout(title_text='Comparision between original close price vs predicted close price',
                  plot_bgcolor='white', font_size=15, font_color='black', legend_title_text='Close Price')
fig.for_each_trace(lambda t:  t.update(name = next(names)))

fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [83], in <cell line: 4>()
#       2 trainPredictPlot = np.empty_like(closedf)
#       3 trainPredictPlot[:, :] = np.nan
# ----> 4 trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
#       5 print("Train predicted data: ", trainPredictPlot.shape)
#       7 # shift test predictions for plotting
#
# ValueError: could not broadcast input array from shape (2035,1) into shape (2028,7,1)

# %% [markdown]
# Essemble Model

# %%
model_1 = model_fit
moddel_2 = history
